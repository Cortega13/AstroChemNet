# %%
import torch
import ChemSurrogate.data_processing as dp
import numpy as np
import gc
import numpy as np
import faiss
import time
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
import os
os.environ['KMP_DUPLICATE_LIB_OK'] = 'TRUE'


species_of_interest = ["H", "H2", "O", "C", "N", "SPlus", "MG", "SIPlus", "CL", "CPlus", "BULK_CO", "BULK_H", "E_minus", "CO", "BULK_CO"]

# %%
training_t, training_indices = dp.load_tensors_from_hdf5(category="training")
training_t = training_t[:, 1:-12]
training_t[:, 6:] = torch.pow(10, 20*training_t[:, 6:]-20)

validation_t, validation_indices = dp.load_tensors_from_hdf5(category="validation")
validation_t = validation_t[:, 1:-12]
validation_t[:, 6:] = torch.pow(10, 20*validation_t[:, 6:]-20)

del validation_indices, training_indices
gc.collect()
# Out:
# 477

# %%
timestep = 80 * 1000

mask1 = training_t[:, 1] == timestep
mask2 = validation_t[:, 1] == timestep

training = training_t[mask1][:, 2:]
validation = validation_t[mask2][:, 2:]

training_np = training.cpu().numpy().astype('float32')
validation_np = validation.cpu().numpy().astype('float32')

physical_params_train = training_np[:, :4]
features_train = training_np[:, 4:]

physical_params_val = validation_np[:, :4]
features_val = validation_np[:, 4:]

start_time = time.time()
index = faiss.IndexFlatL2(4)
index.add(physical_params_train)
indexing_time = time.time() - start_time
print(f"Time to build index: {indexing_time:.6f} seconds")

start_time = time.time()
distances, indices = index.search(physical_params_val, k=1)
search_time = time.time() - start_time
print(f"Time to search all validation samples: {search_time:.6f} seconds")
print(f"Average time per query: {search_time/len(validation_np):.6f} seconds")

mpe_list = []
for i in range(len(validation_np)):
    nn_idx = indices[i][0]
    nn_features = features_train[nn_idx]
    actual_features = features_val[i]
    
    epsilon = 1e-10
    percentage_errors = np.abs((nn_features - actual_features) / (actual_features + epsilon)) * 100
    
    mpe = np.mean(percentage_errors)
    mpe_list.append(mpe)
    
average_mpe = np.mean(mpe_list)
print(f"\nAverage mean percentage error between validation features and nearest neighbor features: {average_mpe:.6f}%")
# Out:
# Time to build index: 0.000000 seconds
# Time to search all validation samples: 0.017242 seconds
# Average time per query: 0.000001 seconds
#
# Average mean percentage error between validation features and nearest neighbor features: 146.953781%

# %%
import numpy as np
import matplotlib.pyplot as plt
import faiss
import time

timesteps = np.arange(1, 101) * 1000  # timesteps from 1000 to 100000
mpe_results = []

for timestep in timesteps:
    mask1 = training_t[:, 1] == timestep
    mask2 = validation_t[:, 1] == timestep
    
    training = training_t[mask1][:, 2:]
    validation = validation_t[mask2][:, 2:]
    
    training_np = training.cpu().numpy().astype('float32')
    validation_np = validation.cpu().numpy().astype('float32')
    
    physical_params_train = training_np[:, :4]
    features_train = training_np[:, 4:]
    
    physical_params_val = validation_np[:, :4]
    features_val = validation_np[:, 4:]
    
    index = faiss.IndexFlatL2(4)
    index.add(physical_params_train)
    
    distances, indices = index.search(physical_params_val, k=1)
    
    mpe_list = []
    for i in range(len(validation_np)):
        nn_idx = indices[i][0]
        nn_features = features_train[nn_idx]
        actual_features = features_val[i]
        
        epsilon = 1e-10
        percentage_errors = np.abs((nn_features - actual_features) / (actual_features + epsilon)) * 100
        
        mpe = np.mean(percentage_errors)
        mpe_list.append(mpe)
    
    average_mpe = np.mean(mpe_list)
    mpe_results.append(average_mpe)
    print(f"Timestep {timestep}: Average MPE = {average_mpe:.6f}%")

# Create plot
plt.figure(figsize=(10, 6))
plt.plot(timesteps, mpe_results, marker='o')
plt.xlabel('Timestep')
plt.ylabel('Mean Percentage Error (%)')
plt.title('Abundances Percentage Error vs Timestep')
plt.grid(True)
plt.show()
# Out:
# Timestep 1000: Average MPE = 251.081848%
# Timestep 2000: Average MPE = 231.059357%
# Timestep 3000: Average MPE = 680.524597%
# Timestep 4000: Average MPE = 510.628906%
# Timestep 5000: Average MPE = 977.486084%
# Timestep 6000: Average MPE = 619.271973%
# Timestep 7000: Average MPE = 365.054382%
# Timestep 8000: Average MPE = 239.620819%
# Timestep 9000: Average MPE = 195.246307%
# Timestep 10000: Average MPE = 198.178787%
# Timestep 11000: Average MPE = 267.092499%
# Timestep 12000: Average MPE = 222.204880%
# Timestep 13000: Average MPE = 183.324249%
# Timestep 14000: Average MPE = 174.841293%
# Timestep 15000: Average MPE = 254.913498%
# Timestep 16000: Average MPE = 208.607849%
# Timestep 17000: Average MPE = 186.961578%
# Timestep 18000: Average MPE = 173.819031%
# Timestep 19000: Average MPE = 171.879807%
# Timestep 20000: Average MPE = 164.431625%
# Timestep 21000: Average MPE = 148.421829%
# Timestep 22000: Average MPE = 152.242737%
# Timestep 23000: Average MPE = 148.889771%
# Timestep 24000: Average MPE = 146.975555%
# Timestep 25000: Average MPE = 148.559402%
# Timestep 26000: Average MPE = 142.920868%
# Timestep 27000: Average MPE = 136.118881%
# Timestep 28000: Average MPE = 138.186905%
# Timestep 29000: Average MPE = 133.859695%
# Timestep 30000: Average MPE = 134.540833%
# Timestep 31000: Average MPE = 137.110474%
# Timestep 32000: Average MPE = 137.832062%
# Timestep 33000: Average MPE = 145.302521%
# Timestep 34000: Average MPE = 149.452911%
# Timestep 35000: Average MPE = 145.346588%
# Timestep 36000: Average MPE = 132.978348%
# Timestep 37000: Average MPE = 121.852936%
# Timestep 38000: Average MPE = 120.593040%
# Timestep 39000: Average MPE = 118.690727%
# Timestep 40000: Average MPE = 122.276672%
# Timestep 41000: Average MPE = 128.156021%
# Timestep 42000: Average MPE = 127.562614%
# Timestep 43000: Average MPE = 123.009354%
# Timestep 44000: Average MPE = 129.307053%
# Timestep 45000: Average MPE = 133.059280%
# Timestep 46000: Average MPE = 128.276047%
# Timestep 47000: Average MPE = 132.050095%
# Timestep 48000: Average MPE = 127.115196%
# Timestep 49000: Average MPE = 129.272293%
# Timestep 50000: Average MPE = 146.177719%
# Timestep 51000: Average MPE = 163.991455%
# Timestep 52000: Average MPE = 163.473602%
# Timestep 53000: Average MPE = 163.593399%
# Timestep 54000: Average MPE = 164.912720%
# Timestep 55000: Average MPE = 161.828323%
# Timestep 56000: Average MPE = 159.916245%
# Timestep 57000: Average MPE = 161.228012%
# Timestep 58000: Average MPE = 161.019394%
# Timestep 59000: Average MPE = 156.699142%
# Timestep 60000: Average MPE = 158.231277%
# Timestep 61000: Average MPE = 156.999359%
# Timestep 62000: Average MPE = 150.888931%
# Timestep 63000: Average MPE = 151.236237%
# Timestep 64000: Average MPE = 147.233795%
# Timestep 65000: Average MPE = 149.430161%
# Timestep 66000: Average MPE = 135.370331%
# Timestep 67000: Average MPE = 138.103912%
# Timestep 68000: Average MPE = 138.983093%
# Timestep 69000: Average MPE = 138.723801%
# Timestep 70000: Average MPE = 138.117462%
# Timestep 71000: Average MPE = 139.771072%
# Timestep 72000: Average MPE = 138.690475%
# Timestep 73000: Average MPE = 140.968201%
# Timestep 74000: Average MPE = 138.731430%
# Timestep 75000: Average MPE = 141.215118%
# Timestep 76000: Average MPE = 143.525528%
# Timestep 77000: Average MPE = 144.613068%
# Timestep 78000: Average MPE = 147.145935%
# Timestep 79000: Average MPE = 146.808441%
# Timestep 80000: Average MPE = 146.953781%
# Timestep 81000: Average MPE = 148.198120%
# Timestep 82000: Average MPE = 150.762222%
# Timestep 83000: Average MPE = 148.576309%
# Timestep 84000: Average MPE = 152.297287%
# Timestep 85000: Average MPE = 149.812561%
# Timestep 86000: Average MPE = 147.717194%
# Timestep 87000: Average MPE = 134.512878%
# Timestep 88000: Average MPE = 127.886200%
# Timestep 89000: Average MPE = 127.015862%
# Timestep 90000: Average MPE = 128.241501%
# Timestep 91000: Average MPE = 129.047394%
# Timestep 92000: Average MPE = 126.823097%
# Timestep 93000: Average MPE = 125.126678%
# Timestep 94000: Average MPE = 123.340187%
# Timestep 95000: Average MPE = 120.250298%
# Timestep 96000: Average MPE = 114.479401%
# Timestep 97000: Average MPE = 115.680649%
# Timestep 98000: Average MPE = 114.358322%
# Timestep 99000: Average MPE = 115.604485%
# Timestep 100000: Average MPE = 116.022484%
